# %% [markdown]
# <a href="https://colab.research.google.com/github/alansdev907-cmyk/ict/blob/main/internship_day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.neighbours import Kneighboursclassifier
metric_k=[]
neighbours=np.arrange(3,15)

for k in neighbors:
  knn_classifier=KneighboursClassifier(n_neighbours=k,metric='minkowski')
  knn_classifier.fix(x_train,y_train)
  y_pred=km_classifier.predict(x_test)
  accuracy=accuracy_score(y_test,y_pred)
  metric_k.append(accuracy)

  metric_k
